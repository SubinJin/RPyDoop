# %%
import pandas as pd
pr_08 = pd.read_csv('death1.csv')

# %%
pr.head()
# Out:
#          지역번호               지역      801      802      803      804      805  \
# 0           1             전국    23188.0  20925.0  22596.0  21057.0  20170.0
# 1  1100000000          서울특별시     3561.0   3233.0   3373.0   3292.0   3061.0
# 2  1111000000       서울특별시 종로구      95.0     55.0     80.0     68.0     64.0
# 3  1111051500  서울특별시 종로구 청운효자동      NaN      NaN      NaN      NaN      NaN
# 4  1111053000    서울특별시 종로구 사직동      3.0      1.0      3.0      3.0      4.0
#
#        806      807      808   ...        1703     1704     1705     1706  \
# 0  19250.0  19718.0  18262.0   ...     25171.0  21758.0  24994.0  23745.0
# 1   3030.0   3070.0   2914.0   ...      3798.0   3398.0   3819.0   3619.0
# 2     69.0     63.0     54.0   ...        75.0     66.0     77.0     57.0
# 3      NaN      NaN      NaN   ...         6.0      2.0      3.0      2.0
# 4      3.0      3.0      4.0   ...         6.0      4.0      5.0      3.0
#
#       1707     1708     1709     1710     1711     1712
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-741c7bc186c2> in <module>()
#       4 for i in range(8,18):
#       5      for j in range(1,13):
# ----> 6         df = death[['지역', form.format(i,j)]]
#       7         pr = df.sort_values(by=[form.format(i,j)],axis=0,na_position='last')
#       8         pr_l20 = pr_l20 + pr['지역'].head(20).tolist()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
# ...

# %%
count = {}
for i in pr_l20:
    try: count[i] += 1
    except: count[i]=1

count
# Out:
# {'강원도 삼척시 가곡면': 3,
#  '강원도 양구군 동면': 12,
#  '강원도 인제군 북면': 3,
#  '강원도 인제군 상남면': 12,
#  '강원도 인제군 인제읍': 11,
#  '강원도 정선군 남면': 3,
#  '강원도 홍천군 내촌면': 8,
#  '강원도 홍천군 서면': 3,
#  '강원도 홍천군 홍천읍': 7,
#  '강원도 화천군 간동면': 12,
#  '강원도 화천군 화천읍': 12,
#  '강원도 횡성군 ': 6,
#  '경기도 이천시 호법면': 2,
#  '경상남도 거창군 가북면': 19,
#  '경상남도 거창군 가조면': 32,
#  '경상남도 거창군 거창읍': 26,
#  '경상남도 거창군 남하면': 7,
#  '경상남도 거창군 마리면': 1,
#  '경상남도 거창군 신원면': 22,
#  '경상남도 고성군 개천면': 2,
#  '경상남도 고성군 구만면': 2,
#  '경상남도 남해군 창선면': 8,
#  '경상남도 산청군 금서면': 1,
#  '경상남도 산청군 신등면': 12,
#  '경상남도 산청군 신안면': 9,
#  '경상남도 양산시 ': 8,
#  '경상남도 양산시 물금읍': 12,
#  '경상남도 양산시 서창동': 9,
#  '경상남도 양산시 소주동': 23,
#  '경상남도 의령군 궁류면': 14,
#  '경상남도 의령군 봉수면': 12,
#  '경상남도 의령군 유곡면': 21,
#  '경상남도 의령군 의령읍': 1,
#  '경상남도 진해시 덕산동': 9,
#  '경상남도 진해시 웅천동': 8,
#  '경상남도 창녕군 장마면': 12,
#  '경상남도 창원시 동읍': 7,
#  '경상남도 통영시 명정동': 11,
#  '경상남도 통영시 북신동': 12,
#  '경상남도 통영시 욕지면': 12,
#  '경상남도 통영시 인평동': 1,
#  '경상남도 통영시 중앙동': 8,
#  '경상남도 통영시 한산면': 3,
#  '경상남도 하동군 화개면': 1,
#  '경상남도 하동군 횡천면': 1,
# ...

# %%
for i,j in sorted(count.items(), key = lambda x:x[1], reverse=True):
     print(i,j)
# Out:
# 경상북도 의성군 춘산면 34
# 경상남도 합천군 봉산면 33
# 경상남도 거창군 가조면 32
# 인천광역시 서구 신현원창동 30
# 경상북도 청송군 안덕면 27
# 경상북도 군위군 우보면 26
# 경상남도 거창군 거창읍 26
# 경상북도 의성군 비안면 26
# 인천광역시 서구 가좌2동 25
# 전라남도 고흥군 두원면 24
# 경상북도 군위군 소보면 24
# 전라남도 구례군 광의면 24
# 경상북도 의성군  24
# 인천광역시 서구 석남2동 24
# 경상북도 영양군 입암면 24
# 경상북도 의성군 옥산면 24
# 경상북도 청송군  24
# 인천광역시 서구 가정3동 24
# 경상북도 의성군 가음면 24
# 인천광역시 서구 가정1동 24
# 경상북도 의성군 안평면 23
# 경상남도 양산시 소주동 23
# 경상남도 거창군 신원면 22
# 경상남도 의령군 유곡면 21
# 경상북도 의성군 안사면 19
# 경상남도 거창군 가북면 19
# 전라남도 고흥군 남양면 17
# 경상북도 예천군 호명면 15
# 전라남도 완도군 노화읍넙도출장소 15
# 경상남도 의령군 궁류면 14
# 전라남도 고흥군 포두면 14
# 경상북도 청송군 부동면 13
# 경상북도 경산시 북부동 13
# 인천광역시 서구 가좌4동 13
# 경상남도 합천군 삼가면 13
# 전라남도 고흥군 도양읍소록출장소 12
# 경상북도 의성군 신평면 12
# 전라남도 완도군 청산면모도출장소 12
# 인천광역시 강화군 서도면볼음출장소 12
# 인천광역시 강화군 서도면 12
# 경상북도 상주시 은척면북부출장소 12
# 충청남도 서천군 시초면 12
# 경상남도 창녕군 장마면 12
# 전라남도 곡성군 목사동면 12
# 전라남도 장성군 남면 12
# 경상북도 군위군  12
# 충청남도 부여군 구룡면 12
# 경상남도 산청군 신등면 12
# 경상북도 영천시 대창면 12
# 경상남도 양산시 물금읍 12
# 경상북도 군위군 군위읍 12
# 경상남도 의령군 봉수면 12
# 충청남도 연기군 동면 12
# 전라남도 보성군 미력면 12
# ...

# %%
result = sorted(count.items(), key= lambda x:x[1], reverse=True)
result
# Out:
# [('경상북도 의성군 춘산면', 34),
#  ('경상남도 합천군 봉산면', 33),
#  ('경상남도 거창군 가조면', 32),
#  ('인천광역시 서구 신현원창동', 30),
#  ('경상북도 청송군 안덕면', 27),
#  ('경상북도 군위군 우보면', 26),
#  ('경상남도 거창군 거창읍', 26),
#  ('경상북도 의성군 비안면', 26),
#  ('인천광역시 서구 가좌2동', 25),
#  ('전라남도 고흥군 두원면', 24),
#  ('경상북도 군위군 소보면', 24),
#  ('전라남도 구례군 광의면', 24),
#  ('경상북도 의성군 ', 24),
#  ('인천광역시 서구 석남2동', 24),
#  ('경상북도 영양군 입암면', 24),
#  ('경상북도 의성군 옥산면', 24),
#  ('경상북도 청송군 ', 24),
#  ('인천광역시 서구 가정3동', 24),
#  ('경상북도 의성군 가음면', 24),
#  ('인천광역시 서구 가정1동', 24),
#  ('경상북도 의성군 안평면', 23),
#  ('경상남도 양산시 소주동', 23),
#  ('경상남도 거창군 신원면', 22),
#  ('경상남도 의령군 유곡면', 21),
#  ('경상북도 의성군 안사면', 19),
#  ('경상남도 거창군 가북면', 19),
#  ('전라남도 고흥군 남양면', 17),
#  ('경상북도 예천군 호명면', 15),
#  ('전라남도 완도군 노화읍넙도출장소', 15),
#  ('경상남도 의령군 궁류면', 14),
#  ('전라남도 고흥군 포두면', 14),
#  ('경상북도 청송군 부동면', 13),
#  ('경상북도 경산시 북부동', 13),
#  ('인천광역시 서구 가좌4동', 13),
#  ('경상남도 합천군 삼가면', 13),
#  ('전라남도 고흥군 도양읍소록출장소', 12),
#  ('경상북도 의성군 신평면', 12),
#  ('전라남도 완도군 청산면모도출장소', 12),
#  ('인천광역시 강화군 서도면볼음출장소', 12),
# ...
