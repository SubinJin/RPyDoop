# %%
import pandas as pd
pr_08_17 = pd.read_csv('C:/Users/DJA/Downloads/데이터/정제자료/인구관련/pop_monthly_rate08_17_u8.csv')

# pr_08_17.dtypes
pr_08_17[['지역번호']] = pr_08_17[['지역번호']].astype(str)
# pr_08_17.dtypes

tmp = pr_08_17[pr_08_17['지역번호'].str[4:]== '000000']
tmp.head()
# Out:
#           지역번호          지역      0801      0802      0803      0804      0805  \
# 0   1100000000     서울특별시    4.257664  4.225334  4.189716  4.169195  4.151027
# 1   1111000000  서울특별시 종로구   2.878918  2.873993  2.850645  2.851153  2.847277
# 22  1114000000   서울특별시 중구   3.057053  3.027444  3.012814  2.996634  2.986344
# 38  1117000000  서울특별시 용산구   3.330504  3.304664  3.289517  3.280052  3.274397
# 55  1120000000  서울특별시 성동구   4.081358  4.044800  4.007542  3.984387  3.969854
#
#         0806      0807      0808    ...         1703      1704      1705  \
# 0   4.136442  4.117900  4.094905    ...     2.325830  2.317569  2.303019
# 1   2.853872  2.853100  2.844921    ...     1.760279  1.760016  1.751165
# 22  2.984163  2.980442  2.971326    ...     1.238390  1.234837  1.223421
# 38  3.277130  3.284478  3.264230    ...     1.422408  1.408022  1.391126
# 55  3.955764  3.933835  3.909984    ...     2.332423  2.329398  2.328196
#
# ...

# %%
tmp.to_csv("pop_city_monthly_rate08_17_u8.csv")
