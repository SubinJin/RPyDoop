# %%
import pandas as pd
prc_08_17 = pd.read_csv('C:/Users/DJA/Downloads/데이터/정제자료/인구관련/pop_city_monthly_rate08_17_u8.csv')

prc_r20 = []

form = '{0:02d}{1:02d}'
# for i in range(8,18):
#      for j in range(1,13):
#         df = prc_08_17[['지역', form.format(i,j)]]
#         prc = df.sort_values(by=[form.format(i,j)],axis=0,na_position='last')
#         prc_r20 = prc_r20 + prc['지역'].head(20).tolist()

for i in range(8,18):
     for j in range(1,13):
        df = prc_08_17[['지역번호', form.format(i,j)]]
        prc = df.sort_values(by=[form.format(i,j)],axis=0,na_position='last')
        prc_r20 = prc_r20 + prc['지역번호'].head(20).tolist()
        
prc_r20
# prc_08_17[['지역번호']]
# Out:
# [4677000000,
#  4772000000,
#  4773000000,
#  4691000000,
#  4886000000,
#  4790000000,
#  4686000000,
#  4776000000,
#  4479000000,
#  4376000000,
#  4872000000,
#  4792000000,
#  4678000000,
#  4889000000,
#  4690000000,
#  4680000000,
#  4884000000,
#  4372000000,
#  4575000000,
#  4775000000,
#  4677000000,
#  4772000000,
#  4773000000,
#  4691000000,
#  4776000000,
#  4790000000,
#  4886000000,
#  4686000000,
#  4889000000,
#  4872000000,
#  4376000000,
#  4479000000,
#  4792000000,
#  4884000000,
#  4678000000,
#  4690000000,
#  4680000000,
#  4372000000,
#  4775000000,
#  4575000000,
#  4677000000,
#  4772000000,
#  4773000000,
#  4691000000,
#  4776000000,
#  4790000000,
#  4886000000,
#  4686000000,
#  4889000000,
#  4872000000,
#  4376000000,
#  4479000000,
#  4884000000,
#  4792000000,
#  4690000000,
#  4678000000,
#  4680000000,
#  4775000000,
#  4372000000,
#  4575000000,
#  4677000000,
#  4772000000,
#  4773000000,
#  4691000000,
#  4776000000,
#  4886000000,
# ...

# %%
count = {}
for i in prc_r20:
    try: count[i] += 1
    except: count[i]=1

count
# Out:
# {4372000000: 33,
#  4376000000: 120,
#  4477000000: 20,
#  4479000000: 120,
#  4575000000: 111,
#  4577000000: 2,
#  4672000000: 67,
#  4677000000: 120,
#  4678000000: 120,
#  4680000000: 27,
#  4686000000: 120,
#  4690000000: 56,
#  4691000000: 120,
#  4772000000: 120,
#  4773000000: 120,
#  4775000000: 120,
#  4776000000: 120,
#  4777000000: 102,
#  4782000000: 69,
#  4790000000: 115,
#  4792000000: 120,
#  4872000000: 119,
#  4884000000: 120,
#  4886000000: 120,
#  4889000000: 119}

# %%
result = sorted(count.items(), key= lambda x:x[1], reverse=True)
result
# Out:
# [(4677000000, 120),
#  (4772000000, 120),
#  (4686000000, 120),
#  (4775000000, 120),
#  (4479000000, 120),
#  (4776000000, 120),
#  (4691000000, 120),
#  (4773000000, 120),
#  (4884000000, 120),
#  (4792000000, 120),
#  (4678000000, 120),
#  (4376000000, 120),
#  (4886000000, 120),
#  (4889000000, 119),
#  (4872000000, 119),
#  (4790000000, 115),
#  (4575000000, 111),
#  (4777000000, 102),
#  (4782000000, 69),
#  (4672000000, 67),
#  (4690000000, 56),
#  (4372000000, 33),
#  (4680000000, 27),
#  (4477000000, 20),
#  (4577000000, 2)]
