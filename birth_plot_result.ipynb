# %%
import pandas as pd
pb_10y = pd.read_csv('C:/Users/DJA/Downloads/데이터/정제자료/인구관련/birth_monthly08_17_u8.csv')


pb_10y.head()
# Out:
#          지역번호               지역     0801     0802     0803     0804     0805  \
# 0           1             전국    41182.0  41537.0  40749.0  39625.0  38863.0
# 1  1100000000          서울특별시     8005.0   8618.0   8338.0   8137.0   8051.0
# 2  1111000000       서울특별시 종로구     109.0    118.0     95.0     82.0     82.0
# 3  1111051500  서울특별시 종로구 청운효자동      NaN      NaN      NaN      NaN      NaN
# 4  1111053000    서울특별시 종로구 사직동      2.0      9.0      2.0      5.0      6.0
#
#       0806     0807     0808   ...        1703     1704     1705     1706  \
# 0  35929.0  38009.0  36235.0   ...     33836.0  29242.0  33174.0  29911.0
# 1   7398.0   7823.0   7394.0   ...      6283.0   5382.0   6041.0   5514.0
# 2     84.0    101.0     87.0   ...        54.0     44.0     63.0     62.0
# 3      NaN      NaN      NaN   ...        12.0      7.0      3.0      7.0
# 4      0.0     11.0      6.0   ...         2.0      4.0      4.0      5.0
#
#       1707     1708     1709     1710     1711     1712
# ...

# %%
rank1 = 4773035000
r_rgl = [4889031000,4888040000,2826057500,4775035000,4772034000,4773039000,4888025000,2826059000,4772031000,4773033000
        ,4775000000,4776031000,2826054400,4677042000,4773000000,2826056000,4773036000,2826054200,4673035000]
# r_rgl = ['4889031000','4888040000','2826057500','4775035000','4772034000','4773039000','4888025000','2826059000','4772031000']

# 1위 '4773035000' 경상북도 의성군 춘산면
rank1_20 = pb_10y[pb_10y['지역번호'] == rank1]
rank1_20 = rank1_20.T
rank1_20 = rank1_20.drop(rank1_20.index[[0]])

rank1_20.head()
# Out:
#               3341
# 지역    경상북도 의성군 춘산면
# 0801             0
# 0802             2
# 0803             2
# 0804             0

# %%
# t = pd.concat([rank11,rank12],axis=1)
# t

for i in r_rgl:
    rank = pb_10y[pb_10y['지역번호'] == i]
    rank = rank.T
    rank = rank.drop(rank.index[[0]])
    rank1_20 = pd.concat([rank1_20,rank],axis=1)

rank1_20
# Out:
#               3341          3787          3783            952           3360  \
# 지역    경상북도 의성군 춘산면  경상남도 합천군 봉산면  경상남도 거창군 가조면  인천광역시 서구 신현원창동  경상북도 청송군 안덕면
# 0801             0             1             6              15             1
# 0802             2             2             1              12             1
# 0803             2             3             1              13             1
# 0804             0             1             3              12             1
# 0805             1             1             0              14             1
# 0806             2             1             1               9             1
# 0807             0             1             0               6             1
# 0808             0             1             2              12             0
# 0809             2             1             1              12             0
# 0810             0             1             3               8             3
# ...

# %%
rank1_20.to_csv("brith_rank1_20.csv",mode='w')
